# %%
from codebase.classes_data import Data
import argparse
import numpy as np
from codebase.file_utils import save_obj, load_obj, make_folder, path_backslash
from codebase.ibis import exp_and_normalise
from run_smclvm import run_smclvm
from scipy.special import logsumexp
from pdb import set_trace

# %%
existing_directory = None
task_handle = 'lvm_vb'
gen_model = False

if existing_directory is None:
    log_dir = make_folder(task_handle)
    print("\n\nCreating new directory: %s" % log_dir)

else:
    log_dir = existing_directory
    log_dir = path_backslash(log_dir)
    print("\n\nReading from existing directory: %s" % log_dir)
# Out:
# Creating new directory: ./log/20210423_110740_lvm_vb/

# %%
# generate data
exp_data = Data(name=task_handle, model_num=1, size=200, random_seed=2)


exp_data.generate()
save_obj(exp_data, "data", log_dir)
model_num = 1

# %%
# %load_ext autotime

ibislvm = run_smclvm(exp_data, model_num, 200, gen_model, log_dir)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 16.343
# /home/konstantinos/anaconda3/envs/smc/lib/python3.7/site-packages/theano/tensor/basic.py:6611: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result[diagonal_slice] = x
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 4.2628
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 29.224
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 21.003
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 37.258
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 14.705
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 12.011
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 34.223
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 44.549
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 28.418
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 29.527
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 62.793
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 30.581
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 30.44
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 74.964
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 69.13
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 20.432
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 13.477
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 8.6577
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 11.897
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 47.925
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 12.633
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 8.6803
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 10.817
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 30.887
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 11.031
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 34.346
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 7.9585
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 30.321
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 2.04
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 14.835
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 43.998
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 10.454
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 20.287
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 4.1656
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 21.106
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 0.95689
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 1.1619
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 13.843
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 53.828
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 34.633
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 17.525
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 16.15
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 40.625
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 14.569
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 20.179
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 25.909
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 34.063
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 6.3177
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 46.371
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 45.415
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 17.117
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 12.489
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 70.108
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 19.83
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 5.9976
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 37.787
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 16.408
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 13.841
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 18.162
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 24.851
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 13.7
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 19.409
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 64.002
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 23.543
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 42.336
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 24.65
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 40.105
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 26.42
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 27.278
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 33.818
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 49.732
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 7.1489
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 28.978
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 22.395
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 20.292
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 19.609
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 17.511
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 23.506
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 24.397
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 0.039781
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 8.4083
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 32.917
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 31.212
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 9.5125
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 19.078
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 27.04
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 8.1307
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 3.1419
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 15.932
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 2.9868
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 28.668
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 32.621
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 12.686
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 35.02
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 34.545
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 15.36
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 3.3309
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 2.2648
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 23.616
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 25.876
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 4.4479
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 24.237
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 9.3644
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 21.054
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 26.481
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 10.044
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 31.376
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 28.983
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 15.607
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 14.814
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 0.13102
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 20.903
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 18.638
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 13.501
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 5.8794
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 14.106
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 24.069
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 11.377
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 23.862
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 20.147
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 24.51
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 33.364
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 15.514
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 37.922
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 19.225
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 31.786
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 27.963
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 8.5764
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 0.87833
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 61.83
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 31.528
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 12.483
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 3.3208
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 4.7226
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 36.245
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 16.754
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 17.688
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 26.951
# INFO:pymc3.variational.inference:Finished [100%]: Average Loss = 13.712
# ---------------------------------------------------------------------
# KeyboardInterrupt                   Traceback (most recent call last)
# <ipython-input-4-ea2a23ef74ae> in <module>
#       1 get_ipython().run_line_magic('load_ext', 'autotime')
#       2
# ----> 3 ibislvm = run_smclvm(exp_data, model_num, 200, gen_model, log_dir)
#
# ~/myPhD/smc2/src/run_smclvm.py in run_smclvm(exp_data, model_num, size, gen_model, log_dir, degeneracy_limit, name)
#      58
#      59     for t in tqdm(range(exp_data.size)):
# ---> 60         particles.sample_latent_variables(exp_data.get_stan_data_at_t(t), t)
#      61         particles.get_theta_incremental_weights(exp_data.get_stan_data_at_t(t), t)
#      62         log_lklhds[t] = particles.get_loglikelihood_estimate()
#
# ~/myPhD/smc2/src/codebase/classes_smclvm.py in sample_latent_variables(self, data, t)
#     106                 data['D'],
#     107                 self.particles['alpha'][m],
# --> 108                 self.particles['beta'][m])
#     109
#     110
#
# ~/myPhD/smc2/src/codebase/ibis_tlk_latent.py in generate_latent_pair_vb(data_y, alpha, beta)
#     154         {
#     155             'alpha':alpha,
# --> 156             'beta':beta,
#     157         }
#     158         )
#
# ~/myPhD/smc2/src/codebase/ibis_tlk_latent.py in get_vb_approx(y, theta)
#     211
#     212 def get_vb_approx(y, theta):
# --> 213     vb_mean, vb_cov = get_vb_params(y, theta)
#     214     if check_posdef(vb_cov) == 0:
#     215         vb_cov = np.eye(theta['beta'].shape[1])
#
# ~/myPhD/smc2/src/codebase/ibis_tlk_latent.py in get_vb_params(y, theta)
#     205         p = pm.invlogit(theta['alpha'] + z @ theta['beta'].T)
#     206         obs = pm.Bernoulli('obs', p=p, observed=y)
# --> 207         advi = pm.fit(method=vb_method, n=10000, progressbar=False)
#     208     vb_mean = advi.mean.eval()
#     209     vb_cov = advi.cov.eval()
#
# ~/anaconda3/envs/smc/lib/python3.7/site-packages/pymc3/variational/inference.py in fit(n, local_rv, method, model, random_seed, start, inf_kwargs, **kwargs)
#     788                         'or Inference instance' %
#     789                         set(_select.keys()))
# --> 790     return inference.fit(n, **kwargs)
#
# ~/anaconda3/envs/smc/lib/python3.7/site-packages/pymc3/variational/inference.py in fit(self, n, score, callbacks, progressbar, **kwargs)
#     129             callbacks = []
#     130         score = self._maybe_score(score)
# --> 131         step_func = self.objective.step_function(score=score, **kwargs)
#     132         with tqdm.trange(n, disable=not progressbar) as progress:
#     133             if score:
#
# ~/anaconda3/envs/smc/lib/python3.7/site-packages/theano/configparser.py in res(*args, **kwargs)
#     115         def res(*args, **kwargs):
#     116             with self:
# --> 117                 return f(*args, **kwargs)
#     118         return res
#     119
#
# ~/anaconda3/envs/smc/lib/python3.7/site-packages/pymc3/variational/opvi.py in step_function(self, obj_n_mc, tf_n_mc, obj_optimizer, test_optimizer, more_obj_params, more_tf_params, more_updates, more_replacements, total_grad_norm_constraint, score, fn_kwargs)
#     318         if score:
#     319             step_fn = theano.function(
# --> 320                 [], updates.loss, updates=updates, **fn_kwargs)
#     321         else:
#     322             step_fn = theano.function([], None, updates=updates, **fn_kwargs)
#
# ~/anaconda3/envs/smc/lib/python3.7/site-packages/theano/compile/function.py in function(inputs, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input)
#     315                    on_unused_input=on_unused_input,
#     316                    profile=profile,
# --> 317                    output_keys=output_keys)
#     318     return fn
#
# ~/anaconda3/envs/smc/lib/python3.7/site-packages/theano/compile/pfunc.py in pfunc(params, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input, output_keys)
#     484                          accept_inplace=accept_inplace, name=name,
#     485                          profile=profile, on_unused_input=on_unused_input,
# --> 486                          output_keys=output_keys)
#     487
#     488
#
# ~/anaconda3/envs/smc/lib/python3.7/site-packages/theano/compile/function_module.py in orig_function(inputs, outputs, mode, accept_inplace, name, profile, on_unused_input, output_keys)
#    1839                   name=name)
#    1840         with theano.change_flags(compute_test_value="off"):
# -> 1841             fn = m.create(defaults)
#    1842     finally:
#    1843         t2 = time.time()
#
# ~/anaconda3/envs/smc/lib/python3.7/site-packages/theano/compile/function_module.py in create(self, input_storage, trustme, storage_map)
#    1713             theano.config.traceback.limit = theano.config.traceback.compile_limit
#    1714             _fn, _i, _o = self.linker.make_thunk(
# -> 1715                 input_storage=input_storage_lists, storage_map=storage_map)
#    1716         finally:
#    1717             theano.config.traceback.limit = limit_orig
#
# ~/anaconda3/envs/smc/lib/python3.7/site-packages/theano/gof/link.py in make_thunk(self, input_storage, output_storage, storage_map)
#     697         return self.make_all(input_storage=input_storage,
#     698                              output_storage=output_storage,
# --> 699                              storage_map=storage_map)[:3]
#     700
#     701     def make_all(self, input_storage, output_storage):
#
# ~/anaconda3/envs/smc/lib/python3.7/site-packages/theano/gof/vm.py in make_all(self, profiler, input_storage, output_storage, storage_map)
#    1089                                                  compute_map,
#    1090                                                  [],
# -> 1091                                                  impl=impl))
#    1092                 linker_make_thunk_time[node] = time.time() - thunk_start
#    1093                 if not hasattr(thunks[-1], 'lazy'):
#
# ~/anaconda3/envs/smc/lib/python3.7/site-packages/theano/gof/op.py in make_thunk(self, node, storage_map, compute_map, no_recycling, impl)
#     953             try:
#     954                 return self.make_c_thunk(node, storage_map, compute_map,
# --> 955                                          no_recycling)
#     956             except (NotImplementedError, utils.MethodNotDefined):
#     957                 # We requested the c code, so don't catch the error.
#
# ~/anaconda3/envs/smc/lib/python3.7/site-packages/theano/gof/op.py in make_c_thunk(self, node, storage_map, compute_map, no_recycling)
#     856         _logger.debug('Trying CLinker.make_thunk')
#     857         outputs = cl.make_thunk(input_storage=node_input_storage,
# --> 858                                 output_storage=node_output_storage)
#     859         thunk, node_input_filters, node_output_filters = outputs
#     860
#
# ~/anaconda3/envs/smc/lib/python3.7/site-packages/theano/gof/cc.py in make_thunk(self, input_storage, output_storage, storage_map, keep_lock)
#    1215         cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#    1216             input_storage, output_storage, storage_map,
# -> 1217             keep_lock=keep_lock)
#    1218
#    1219         res = _CThunk(cthunk, init_tasks, tasks, error_storage, module)
#
# ~/anaconda3/envs/smc/lib/python3.7/site-packages/theano/gof/cc.py in __compile__(self, input_storage, output_storage, storage_map, keep_lock)
#    1155                                             output_storage,
#    1156                                             storage_map,
# -> 1157                                             keep_lock=keep_lock)
#    1158         return (thunk,
#    1159                 module,
#
# ~/anaconda3/envs/smc/lib/python3.7/site-packages/theano/gof/cc.py in cthunk_factory(self, error_storage, in_storage, out_storage, storage_map, keep_lock)
#    1622                 node.op.prepare_node(node, storage_map, None, 'c')
#    1623             module = get_module_cache().module_from_key(
# -> 1624                 key=key, lnk=self, keep_lock=keep_lock)
#    1625
#    1626         vars = self.inputs + self.outputs + self.orphans
#
# ~/anaconda3/envs/smc/lib/python3.7/site-packages/theano/gof/cmodule.py in module_from_key(self, key, lnk, keep_lock)
#    1153         # Is the source code already in the cache?
#    1154         module_hash = get_module_hash(src_code, key)
# -> 1155         module = self._get_from_hash(module_hash, key, keep_lock=keep_lock)
#    1156         if module is not None:
#    1157             return module
#
# ~/anaconda3/envs/smc/lib/python3.7/site-packages/theano/gof/cmodule.py in _get_from_hash(self, module_hash, key, keep_lock)
#    1063                 if (key[0] and not key_broken and
#    1064                         self.check_for_broken_eq):
# -> 1065                     self.check_key(key, key_data.key_pkl)
#    1066             self._update_mappings(key, key_data, module.__file__, check_in_keys=not key_broken)
#    1067             return module
#
# ~/anaconda3/envs/smc/lib/python3.7/site-packages/theano/gof/cmodule.py in check_key(self, key, key_pkl)
#    1234             try:
#    1235                 with open(key_pkl, 'rb') as f:
# -> 1236                     key_data = pickle.load(f)
#    1237                 break
#    1238             except EOFError:
#
# ~/anaconda3/envs/smc/lib/python3.7/site-packages/theano/gof/utils.py in __hash__(self)
#     187
#     188             if '__hash__' not in dct:
# --> 189                 def __hash__(self):
#     190                     return hash((type(self),
#     191                                  tuple(getattr(self, a) for a in props)))
#
# KeyboardInterrupt:
# time: 8min 5s (started: 2021-04-23 11:07:40 -04:00)

# %% [markdown]
# ##
